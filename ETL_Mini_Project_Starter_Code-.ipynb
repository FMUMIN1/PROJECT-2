# %%
# Import the dependencies
import pandas as pd
from pprint import pprint
from pymongo import MongoClient
from sqlalchemy import create_engine
from sqlalchemy import Column, Integer, String, Float
from sqlalchemy.ext.declarative import declarative_base

# %% [markdown]
# # NETFLIX

# %%
#raw data
CREDNET_df = pd.read_csv('NETFLIX/titles.csv')
CREDNET_df.head()
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 4  tm120801                      The Dirty Dozen  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
# 4  12 American military prisoners in World War II...          1967
#
#   age_certification  runtime                                       genres  \
# 0             TV-MA       51                            ['documentation']
# 1                 R      114                           ['drama', 'crime']
# 2                 R      109  ['drama', 'action', 'thriller', 'european']
# 3                PG       91              ['fantasy', 'action', 'comedy']
# 4               NaN      150                            ['war', 'action']
#
#   production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# 0               ['US']      1.0        NaN         NaN         NaN
# 1               ['US']      NaN  tt0075314         8.2    808582.0
# 2               ['US']      NaN  tt0068473         7.7    107673.0
# 3               ['GB']      NaN  tt0071853         8.2    534486.0
# 4         ['GB', 'US']      NaN  tt0061578         7.7     72662.0
#
#    tmdb_popularity  tmdb_score
# 0            0.600         NaN
# 1           40.965       8.179
# 2           10.010       7.300
# 3           15.461       7.811
# 4           20.398       7.600

# %%
#select desired attributes
NET_SELECTED = CREDNET_df[['id','title','type','release_year', 'genres','production_countries', 'imdb_score','imdb_votes']]
NET_SELECTED.head()
# Out:
#          id                                title   type  release_year  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW          1945
# 1   tm84618                          Taxi Driver  MOVIE          1976
# 2  tm154986                          Deliverance  MOVIE          1972
# 3  tm127384      Monty Python and the Holy Grail  MOVIE          1975
# 4  tm120801                      The Dirty Dozen  MOVIE          1967
#
#                                         genres production_countries  \
# 0                            ['documentation']               ['US']
# 1                           ['drama', 'crime']               ['US']
# 2  ['drama', 'action', 'thriller', 'european']               ['US']
# 3              ['fantasy', 'action', 'comedy']               ['GB']
# 4                            ['war', 'action']         ['GB', 'US']
#
#    imdb_score  imdb_votes
# 0         NaN         NaN
# 1         8.2    808582.0
# 2         7.7    107673.0
# 3         8.2    534486.0
# 4         7.7     72662.0

# %% [markdown]
# # NETFLIX SHOWS CLEAN UP

# %%
#split the TVSHOWS 
NET_SHOWS = NET_SELECTED.loc[NET_SELECTED["type"] == "SHOW", :]
NET_SHOWS.head()
# Out:
#           id                                title  type  release_year  \
# 0   ts300399  Five Came Back: The Reference Films  SHOW          1945
# 5    ts22164         Monty Python's Flying Circus  SHOW          1969
# 26   ts45948     Monty Python's Fliegender Zirkus  SHOW          1972
# 35   ts20681                             Seinfeld  SHOW          1989
# 44   ts22082                         Knight Rider  SHOW          1982
#
#                                    genres production_countries  imdb_score  \
# 0                       ['documentation']               ['US']         NaN
# 5                  ['comedy', 'european']               ['GB']         8.8
# 26                             ['comedy']                   []         8.1
# 35                             ['comedy']               ['US']         8.9
# 44  ['scifi', 'action', 'crime', 'drama']               ['US']         6.9
#
#     imdb_votes
# 0          NaN
# 5      73424.0
# 26      2151.0
# 35    308824.0
# 44     34115.0

# %%
#drop NAN in all colums
CLEAN_NANS=NET_SHOWS.dropna() 
CLEAN_NANS.head()
# Out:
#          id                             title  type  release_year  \
# 5   ts22164      Monty Python's Flying Circus  SHOW          1969
# 26  ts45948  Monty Python's Fliegender Zirkus  SHOW          1972
# 35  ts20681                          Seinfeld  SHOW          1989
# 44  ts22082                      Knight Rider  SHOW          1982
# 45  ts21715                  Thomas & Friends  SHOW          1984
#
#                                                genres production_countries  \
# 5                              ['comedy', 'european']               ['GB']
# 26                                         ['comedy']                   []
# 35                                         ['comedy']               ['US']
# 44              ['scifi', 'action', 'crime', 'drama']               ['US']
# 45  ['animation', 'family', 'comedy', 'fantasy', '...               ['GB']
#
#     imdb_score  imdb_votes
# 5          8.8     73424.0
# 26         8.1      2151.0
# 35         8.9    308824.0
# 44         6.9     34115.0
# 45         6.5      5104.0

# %%
#ascending order or IMDB SCORES AND VOTES
FINAL_NETSHOW = CLEAN_NANS.sort_values(['imdb_score', 'imdb_votes'],
              ascending = [False, False])
FINAL_NETSHOW.head()
# Out:
#             id                       title  type  release_year  \
# 2658  ts265844                    #ABtalks  SHOW          2018
# 216        ts4                Breaking Bad  SHOW          2008
# 564   ts160526                    Khawatir  SHOW          2005
# 233     ts3371  Avatar: The Last Airbender  SHOW          2005
# 3147   ts85398                  Our Planet  SHOW          2019
#
#                                                  genres production_countries  \
# 2658                                                 []                   []
# 216                      ['drama', 'crime', 'thriller']               ['US']
# 564                                         ['reality']                   []
# 233   ['scifi', 'animation', 'action', 'family', 'fa...               ['US']
# 3147                                  ['documentation']               ['GB']
#
#       imdb_score  imdb_votes
# 2658         9.6         7.0
# 216          9.5   1775990.0
# 564          9.5      3115.0
# 233          9.3    303666.0
# 3147         9.3     42259.0

# %% [markdown]
# # NETFLIX MOVIES CLEAN UP

# %%
#split the MOVIES
NET_MOVIES = NET_SELECTED.loc[NET_SELECTED["type"] == "MOVIE", :]
NET_MOVIES.head()
# Out:
#          id                            title   type  release_year  \
# 1   tm84618                      Taxi Driver  MOVIE          1976
# 2  tm154986                      Deliverance  MOVIE          1972
# 3  tm127384  Monty Python and the Holy Grail  MOVIE          1975
# 4  tm120801                  The Dirty Dozen  MOVIE          1967
# 6   tm70993                    Life of Brian  MOVIE          1979
#
#                                         genres production_countries  \
# 1                           ['drama', 'crime']               ['US']
# 2  ['drama', 'action', 'thriller', 'european']               ['US']
# 3              ['fantasy', 'action', 'comedy']               ['GB']
# 4                            ['war', 'action']         ['GB', 'US']
# 6                                   ['comedy']               ['GB']
#
#    imdb_score  imdb_votes
# 1         8.2    808582.0
# 2         7.7    107673.0
# 3         8.2    534486.0
# 4         7.7     72662.0
# 6         8.0    395024.0

# %%
#drop NAN in all colums
CLEAN_NANM=NET_MOVIES.dropna() 
CLEAN_NANM.head()
# Out:
#          id                            title   type  release_year  \
# 1   tm84618                      Taxi Driver  MOVIE          1976
# 2  tm154986                      Deliverance  MOVIE          1972
# 3  tm127384  Monty Python and the Holy Grail  MOVIE          1975
# 4  tm120801                  The Dirty Dozen  MOVIE          1967
# 6   tm70993                    Life of Brian  MOVIE          1979
#
#                                         genres production_countries  \
# 1                           ['drama', 'crime']               ['US']
# 2  ['drama', 'action', 'thriller', 'european']               ['US']
# 3              ['fantasy', 'action', 'comedy']               ['GB']
# 4                            ['war', 'action']         ['GB', 'US']
# 6                                   ['comedy']               ['GB']
#
#    imdb_score  imdb_votes
# 1         8.2    808582.0
# 2         7.7    107673.0
# 3         8.2    534486.0
# 4         7.7     72662.0
# 6         8.0    395024.0

# %%
#ascending order or IMDB SCORES AND VOTES
FINAL_NETMOVIE = CLEAN_NANM.sort_values(['imdb_score', 'imdb_votes'],
              ascending = [False, False])
FINAL_NETMOVIE.head()
# Out:
#             id                                     title   type  release_year  \
# 4771  tm996762                                     Major  MOVIE          2022
# 1092  tm250247         Chhota Bheem & Krishna vs Zimbara  MOVIE          2013
# 3271  tm853783  David Attenborough: A Life on Our Planet  MOVIE          2020
# 2547  tm432327                         C/o Kancharapalem  MOVIE          2018
# 237    tm92641                                 Inception  MOVIE          2010
#
#                                         genres production_countries  \
# 4771                       ['action', 'drama']               ['IN']
# 1092                             ['animation']                   []
# 3271                         ['documentation']               ['GB']
# 2547                                 ['drama']               ['IN']
# 237   ['action', 'scifi', 'music', 'thriller']         ['US', 'GB']
#
#       imdb_score  imdb_votes
# 4771         9.1      7576.0
# 1092         9.1        16.0
# 3271         8.9     31625.0
# 2547         8.9      6842.0
# 237          8.8   2294231.0

# %% [markdown]
# # PARAMOUNT

# %%
CREDPAR_df = pd.read_csv('PARAMOUNT/titles.csv')
CREDPAR_df.head()
# Out:
#          id                                             title   type  \
# 0   tm19248                                       The General  MOVIE
# 1   tm83884                                   His Girl Friday  MOVIE
# 2   tm19424                                            Detour  MOVIE
# 3  tm112005                                         Marihuana  MOVIE
# 4   tm22806  Intolerance: Love's Struggle Throughout the Ages  MOVIE
#
#                                          description  release_year  \
# 0  During America’s Civil War, Union spies steal ...          1926
# 1  Hildy, the journalist former wife of newspaper...          1940
# 2  The life of Al Roberts, a pianist in a New Yor...          1945
# 3  A young girl named Burma attends a beach party...          1936
# 4  The story of a poor young woman, separated by ...          1916
#
#   age_certification  runtime  \
# 0               NaN       78
# 1               NaN       92
# 2               NaN       66
# 3               NaN       57
# 4               NaN      197
#
#                                               genres production_countries  \
# 0  ['action', 'drama', 'war', 'western', 'comedy'...               ['US']
# 1                     ['comedy', 'drama', 'romance']               ['US']
# 2                     ['thriller', 'drama', 'crime']               ['US']
# 3                                 ['crime', 'drama']               ['US']
# 4                               ['history', 'drama']               ['US']
#
#    seasons    imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 0      NaN  tt0017925         8.2     89766.0            8.647         8.0
# 1      NaN  tt0032599         7.8     57835.0           11.270         7.4
# 2      NaN  tt0037638         7.3     17233.0            7.757         7.2
# 3      NaN  tt0026683         4.0       864.0            3.748         3.6
# 4      NaN  tt0006864         7.7     15242.0            9.412         7.2

# %%
#select desired attributes
PAR_SELECTED = CREDPAR_df[['id','title','type','release_year', 'genres','production_countries', 'imdb_score','imdb_votes']]
PAR_SELECTED.head()
# Out:
#          id                                             title   type  \
# 0   tm19248                                       The General  MOVIE
# 1   tm83884                                   His Girl Friday  MOVIE
# 2   tm19424                                            Detour  MOVIE
# 3  tm112005                                         Marihuana  MOVIE
# 4   tm22806  Intolerance: Love's Struggle Throughout the Ages  MOVIE
#
#    release_year                                             genres  \
# 0          1926  ['action', 'drama', 'war', 'western', 'comedy'...
# 1          1940                     ['comedy', 'drama', 'romance']
# 2          1945                     ['thriller', 'drama', 'crime']
# 3          1936                                 ['crime', 'drama']
# 4          1916                               ['history', 'drama']
#
#   production_countries  imdb_score  imdb_votes
# 0               ['US']         8.2     89766.0
# 1               ['US']         7.8     57835.0
# 2               ['US']         7.3     17233.0
# 3               ['US']         4.0       864.0
# 4               ['US']         7.7     15242.0

# %% [markdown]
# # PARAMOUNT SHOW CLEAN UP

# %%
#split the TVSHOWS 
PAR_SHOWS = PAR_SELECTED.loc[PAR_SELECTED["type"] == "SHOW", :]
PAR_SHOWS.head()
# Out:
#           id              title  type  release_year  \
# 550  ts22109  The Twilight Zone  SHOW          1959
# 551  ts21236          Star Trek  SHOW          1966
# 555  ts20005        I Love Lucy  SHOW          1951
# 557  ts21682         Happy Days  SHOW          1974
# 559  ts22170           Gunsmoke  SHOW          1955
#
#                                                 genres production_countries  \
# 550  ['scifi', 'drama', 'fantasy', 'horror', 'thril...               ['US']
# 551                                ['scifi', 'action']               ['US']
# 555                               ['comedy', 'family']               ['US']
# 557  ['comedy', 'history', 'music', 'family', 'thri...               ['US']
# 559                              ['action', 'western']               ['US']
#
#      imdb_score  imdb_votes
# 550         9.1     80605.0
# 551         8.4     81281.0
# 555         8.5     25944.0
# 557         7.3        32.0
# 559         8.0      6859.0

# %%
#drop NAN in all colums
CLEAN_NANpS=PAR_SHOWS.dropna() 
CLEAN_NANpS.head()
# Out:
#           id              title  type  release_year  \
# 550  ts22109  The Twilight Zone  SHOW          1959
# 551  ts21236          Star Trek  SHOW          1966
# 555  ts20005        I Love Lucy  SHOW          1951
# 557  ts21682         Happy Days  SHOW          1974
# 559  ts22170           Gunsmoke  SHOW          1955
#
#                                                 genres production_countries  \
# 550  ['scifi', 'drama', 'fantasy', 'horror', 'thril...               ['US']
# 551                                ['scifi', 'action']               ['US']
# 555                               ['comedy', 'family']               ['US']
# 557  ['comedy', 'history', 'music', 'family', 'thri...               ['US']
# 559                              ['action', 'western']               ['US']
#
#      imdb_score  imdb_votes
# 550         9.1     80605.0
# 551         8.4     81281.0
# 555         8.5     25944.0
# 557         7.3        32.0
# 559         8.0      6859.0

# %%
#ascending order of IMDB SCORES AND VOTES
FINAL_PARSHOWS = CLEAN_NANpS.sort_values(['imdb_score', 'imdb_votes'],
              ascending = [False, False]).reset_index(drop=True)
FINAL_PARSHOWS.head()
# Out:
#          id                       title  type  release_year  \
# 0  ts107506     Orangutan Jungle School  SHOW          2018
# 1    ts3371  Avatar: The Last Airbender  SHOW          2005
# 2   ts22109           The Twilight Zone  SHOW          1959
# 3  ts166066            L.A. Frock Stars  SHOW          2013
# 4  ts125631           Ol Pejeta Diaries  SHOW          2015
#
#                                               genres production_countries  \
# 0                                  ['documentation']         ['AU', 'US']
# 1  ['scifi', 'family', 'fantasy', 'animation', 'a...               ['US']
# 2  ['scifi', 'drama', 'fantasy', 'horror', 'thril...               ['US']
# 3                                        ['reality']               ['ZA']
# 4                                                 []                   []
#
#    imdb_score  imdb_votes
# 0         9.4       143.0
# 1         9.3    297336.0
# 2         9.1     80605.0
# 3         9.0        41.0
# 4         9.0         6.0

# %% [markdown]
# # PARAMOUNT MOVIES CLEAN UP

# %%
#split the MOVIES
PAR_MOVIES = PAR_SELECTED.loc[PAR_SELECTED["type"] == "MOVIE", :]
PAR_MOVIES.head()
# Out:
#          id                                             title   type  \
# 0   tm19248                                       The General  MOVIE
# 1   tm83884                                   His Girl Friday  MOVIE
# 2   tm19424                                            Detour  MOVIE
# 3  tm112005                                         Marihuana  MOVIE
# 4   tm22806  Intolerance: Love's Struggle Throughout the Ages  MOVIE
#
#    release_year                                             genres  \
# 0          1926  ['action', 'drama', 'war', 'western', 'comedy'...
# 1          1940                     ['comedy', 'drama', 'romance']
# 2          1945                     ['thriller', 'drama', 'crime']
# 3          1936                                 ['crime', 'drama']
# 4          1916                               ['history', 'drama']
#
#   production_countries  imdb_score  imdb_votes
# 0               ['US']         8.2     89766.0
# 1               ['US']         7.8     57835.0
# 2               ['US']         7.3     17233.0
# 3               ['US']         4.0       864.0
# 4               ['US']         7.7     15242.0

# %%
#drop NAN in all colums
CLEAN_NANpM=PAR_MOVIES.dropna() 
CLEAN_NANpM.head()
# Out:
#          id                                             title   type  \
# 0   tm19248                                       The General  MOVIE
# 1   tm83884                                   His Girl Friday  MOVIE
# 2   tm19424                                            Detour  MOVIE
# 3  tm112005                                         Marihuana  MOVIE
# 4   tm22806  Intolerance: Love's Struggle Throughout the Ages  MOVIE
#
#    release_year                                             genres  \
# 0          1926  ['action', 'drama', 'war', 'western', 'comedy'...
# 1          1940                     ['comedy', 'drama', 'romance']
# 2          1945                     ['thriller', 'drama', 'crime']
# 3          1936                                 ['crime', 'drama']
# 4          1916                               ['history', 'drama']
#
#   production_countries  imdb_score  imdb_votes
# 0               ['US']         8.2     89766.0
# 1               ['US']         7.8     57835.0
# 2               ['US']         7.3     17233.0
# 3               ['US']         4.0       864.0
# 4               ['US']         7.7     15242.0

# %%
#ascending order of IMDB SCORES AND VOTES
FINAL_PARMOVIE = CLEAN_NANpM.sort_values(['imdb_score', 'imdb_votes'],
              ascending = [False, False]).reset_index(drop=True)
FINAL_PARMOVIE.head()
# Out:
#           id                    title   type  release_year  \
# 0  tm1175333       The Loyola Project  MOVIE          2022
# 1   tm155580            The Godfather  MOVIE          1972
# 2   tm112061   The Godfather: Part II  MOVIE          1974
# 3   tm112130             Pulp Fiction  MOVIE          1994
# 4   tm139219  Florence Foster Jenkins  MOVIE          2016
#
#                                   genres production_countries  imdb_score  \
# 0                      ['documentation']                   []         9.4
# 1                     ['drama', 'crime']               ['US']         9.2
# 2                     ['drama', 'crime']               ['US']         9.0
# 3         ['thriller', 'crime', 'drama']               ['US']         8.9
# 4  ['drama', 'crime', 'music', 'comedy']         ['US', 'GB']         8.9
#
#    imdb_votes
# 0        10.0
# 1   1780564.0
# 2   1230117.0
# 3   1982722.0
# 4         9.0

# %% [markdown]
# # MOVIES MERGE

# %%
# merge netflix and paramount movies dataframes
movies = [FINAL_NETMOVIE, FINAL_PARMOVIE]
movies_df = pd.concat(movies)
movies_df.head()
# Out:
#             id                                     title   type  release_year  \
# 4771  tm996762                                     Major  MOVIE          2022
# 1092  tm250247         Chhota Bheem & Krishna vs Zimbara  MOVIE          2013
# 3271  tm853783  David Attenborough: A Life on Our Planet  MOVIE          2020
# 2547  tm432327                         C/o Kancharapalem  MOVIE          2018
# 237    tm92641                                 Inception  MOVIE          2010
#
#                                         genres production_countries  \
# 4771                       ['action', 'drama']               ['IN']
# 1092                             ['animation']                   []
# 3271                         ['documentation']               ['GB']
# 2547                                 ['drama']               ['IN']
# 237   ['action', 'scifi', 'music', 'thriller']         ['US', 'GB']
#
#       imdb_score  imdb_votes
# 4771         9.1      7576.0
# 1092         9.1        16.0
# 3271         8.9     31625.0
# 2547         8.9      6842.0
# 237          8.8   2294231.0

# %% [markdown]
# # SHOWS MERGE

# %%
# merge netflix and paramount shows dataframes
shows = [FINAL_NETSHOW, FINAL_PARSHOWS]
shows_df = pd.concat(shows)
shows_df.head()
# Out:
#             id                       title  type  release_year  \
# 2658  ts265844                    #ABtalks  SHOW          2018
# 216        ts4                Breaking Bad  SHOW          2008
# 564   ts160526                    Khawatir  SHOW          2005
# 233     ts3371  Avatar: The Last Airbender  SHOW          2005
# 3147   ts85398                  Our Planet  SHOW          2019
#
#                                                  genres production_countries  \
# 2658                                                 []                   []
# 216                      ['drama', 'crime', 'thriller']               ['US']
# 564                                         ['reality']                   []
# 233   ['scifi', 'animation', 'action', 'family', 'fa...               ['US']
# 3147                                  ['documentation']               ['GB']
#
#       imdb_score  imdb_votes
# 2658         9.6         7.0
# 216          9.5   1775990.0
# 564          9.5      3115.0
# 233          9.3    303666.0
# 3147         9.3     42259.0
